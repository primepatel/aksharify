# %%
from src.aksharify import TextArt

# input image file
art1 = TextArt("julia.png", chars="01")
art2 = TextArt("sample5.png", chars="01") # http://paulbourke.net/fractals/juliaset/

# %%
art1.set_dim(160)
art2.set_dim(160)
art1.asciify()
art2.asciify()

# %%
art1.svgify()
art2.svgify()
art1.htmlify()
art2.htmlify()

# %%
art1.txt_output("output1")
art2.txt_output("output2")
art1.svg_output("output1")
art2.svg_output("output2")
art1.html_output("output1")
art2.html_output("output2")
